# %%
#!pip install yfinance

# %%
#pip install yfinance --upgrade --no-cache-dir

# %%
#pip install pandas-datareader

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2010-01-01", end="2024-02-23")
# Out:
# C:\Users\rites\anaconda3\lib\site-packages\yfinance\base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()
# [*********************100%%**********************]  1 of 1 completed

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error as mse
import numpy as np 
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.api import SimpleExpSmoothing, Holt
import matplotlib.pyplot as plt

# %%
data[["Open",'Close']].plot()
plt.show()

# %%
# download dataframe
df_nifty = pdr.get_data_yahoo("^NSEI", start="2000-01-01", end="2024-02-23" )
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_nifty[["Open",'Close']].plot()
plt.show()

# %%
df_tata = pdr.get_data_yahoo("TATAMOTORS.NS", start="2020-12-20", end="2024-02-13",interval="5m")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['TATAMOTORS.NS']: Exception('%ticker%: 5m data not available for startTime=1608402600 and endTime=1707762600. The requested range must be within the last 60 days.')

# %%
df_tata
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
df_tata.to_csv("TataMotors.csv")

# %%
df_tata["Open"].plot()
plt.show()

# %%
df_maruti = pdr.get_data_yahoo("MARUTI.NS", start="2000-01-01", end="2024-02-13")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_maruti[["High",'Low']].plot()
plt.show()

# %%
df_maruti = pdr.get_data_yahoo("MARUTI.NS", start="2024-01-01", end="2024-02-16",interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_maruti
# Out:
#                     Open          High           Low         Close  \
# Date
# 2024-01-01  10345.000000  10345.000000  10214.650391  10283.299805
# 2024-01-02  10283.299805  10294.700195  10151.049805  10197.750000
# 2024-01-03  10200.000000  10210.000000  10065.000000  10077.650391
# 2024-01-04  10100.000000  10120.000000   9985.549805  10015.299805
# 2024-01-05  10010.650391  10075.000000   9970.000000  10017.000000
# 2024-01-08  10005.000000  10128.950195   9911.900391   9946.700195
# 2024-01-09   9975.000000  10042.650391   9890.000000  10024.099609
# 2024-01-10  10049.950195  10050.750000   9950.000000  10010.200195
# 2024-01-11  10025.099609  10124.099609  10000.000000  10011.099609
# 2024-01-12  10025.000000  10044.950195   9935.950195   9965.650391
# 2024-01-15   9985.099609  10098.799805   9948.000000  10086.900391
# 2024-01-16  10086.849609  10240.000000  10060.000000  10183.549805
# 2024-01-17  10124.000000  10161.799805   9996.450195  10051.700195
# ...

# %%
def stock_df(tickers, start_dt, end_dt):
    start_date = pd.to_datetime(start_dt)
    end_date = pd.to_datetime(end_dt)
    
    period_limit = pd.DateOffset(months=1)
    stock_data = pd.DataFrame()
    
    while start_date <= end_date:
        # Calculate the end date for this period
        period_end = min(start_date + period_limit, end_date)

        # Download stock data for this period
        data = yf.download(tickers, start=start_date, end=period_end)

        # Concatenate the data with the existing DataFrame
        stock_data = pd.concat([stock_data, data])

        # Move to the next period
        start_date = period_end + pd.Timedelta(days=1)
    
    return stock_data

# %%
stock_df("^NSEI","2010-01-01","2024-02-13")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
def stock_df_1m(tickers, start_dt, end_dt):
    start_date = pd.to_datetime(start_dt)
    end_date = pd.to_datetime(end_dt)
    
    period_limit = pd.DateOffset(months=2)
    stock_data = pd.DataFrame()
    
    while start_date <= end_date:
        # Calculate the end date for this period
        period_end = min(start_date + period_limit, end_date)

        # Download stock data for this period
        data = yf.download(tickers, start=start_date, end=period_end, interval='5m')

        # Concatenate the data with the existing DataFrame
        stock_data = pd.concat([stock_data, data])

        # Move to the next period
        start_date = period_end + pd.Timedelta(days=1)
    
    return stock_data.head()

# %%
stock_df_1m("MARUTI.NS","2020-01-01","2024-02-13")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MARUTI.NS']: Exception('%ticker%: 5m data not available for startTime=1577817000 and endTime=1583001000. The requested range must be within the last 60 days.')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MARUTI.NS']: Exception('%ticker%: 5m data not available for startTime=1583087400 and endTime=1588357800. The requested range must be within the last 60 days.')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MARUTI.NS']: Exception('%ticker%: 5m data not available for startTime=1588444200 and endTime=1593714600. The requested range must be within the last 60 days.')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ...

# %%
start_date = pd.to_datetime("2020-01-01")
end_date = pd.to_datetime("2024-02-13")

# %%
period_limit = pd.DateOffset(months=2)

# %%
period_end = min(start_date + period_limit, end_date)

# %%
period_end
# Out:
# Timestamp('2020-03-01 00:00:00')

# %%
def stock_df_(tickers, start_dt, end_dt):
    start_date = pd.to_datetime(start_dt)
    end_date = pd.to_datetime(end_dt)
    
    period_limit = pd.DateOffset(months=2)
    stock_data = pd.DataFrame()
    
    while start_date <= end_date:
        # Calculate the end date for this period
        period_end = min(start_date + period_limit, end_date)

        # Download stock data for this period
        data = yf.download(tickers, start=start_date, end=period_end, interval='5m')

        # Concatenate the data with the existing DataFrame
        stock_data = pd.concat([stock_data, data])

        # Move to the next period
        start_date = period_end + pd.Timedelta(days=1)
    
    return stock_data.head()

# %%
stock_data = stock_df("^NSEI","2010-01-01","2024-02-13")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///stock_data.db')
stock_data.to_sql('stock_data_table', engine, if_exists='replace', index=True)
# Out:
# 3352

# %%
nhpc=stock_df("NHPC.NS","2020-01-01","2024-02-14")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
nhpc
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-01   23.900000   24.100000   23.900000   24.000000   19.031582
# 2020-01-02   24.000000   24.100000   24.000000   24.000000   19.031582
# 2020-01-03   24.000000   24.100000   24.000000   24.049999   19.071230
# 2020-01-06   24.000000   24.049999   23.900000   23.950001   18.991934
# 2020-01-07   23.950001   24.100000   23.950001   23.950001   18.991934
# ...                ...         ...         ...         ...         ...
# 2024-02-07  102.949997  105.250000  100.800003  102.699997  102.699997
# 2024-02-08  103.750000  104.750000  100.000000  101.500000  101.500000
# 2024-02-09  102.199997  102.199997   92.500000   96.250000   96.250000
# 2024-02-12   95.500000   95.900002   77.650002   81.000000   81.000000
# 2024-02-13   80.949997   87.849998   77.500000   85.800003   85.800003
#
#                Volume
# Date
# 2020-01-01     362729
# 2020-01-02     945076
# 2020-01-03    1034706
# ...

# %%
tcs=stock_df("TCS.NS", "2010-01-01","2024-02-14")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
tcs
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04   377.399994   379.450012   374.524994   375.825012   284.856201
# 2010-01-05   377.500000   379.774994   373.274994   375.924988   284.932159
# 2010-01-06   375.924988   376.100006   366.500000   367.424988   278.489441
# 2010-01-07   367.750000   369.700012   355.500000   357.200012   270.739502
# 2010-01-08   358.000000   359.250000   348.250000   349.899994   265.206543
# ...                 ...          ...          ...          ...          ...
# 2024-02-07  4153.000000  4155.000000  4073.949951  4083.399902  4083.399902
# 2024-02-08  4090.000000  4158.000000  4086.050049  4134.100098  4134.100098
# 2024-02-09  4136.549805  4184.750000  4100.000000  4133.700195  4133.700195
# 2024-02-12  4130.000000  4159.600098  4105.549805  4120.700195  4120.700195
# 2024-02-13  4125.450195  4170.000000  4081.500000  4149.500000  4149.500000
#
#              Volume
# Date
# 2010-01-04  1963682
# ...

# %%
nhpc["Open"].plot()
plt.show()

# %%
tcs["Open"].plot()
plt.show()

# %%
import pandas as pd
from sqlalchemy import create_engine

# Assuming stock_data is already loaded with the stock data

# Add a new column for year and month
stock_data['Year'] = stock_data.index.year
stock_data['Month'] = stock_data.index.month

# Create a connection to the MySQL database
engine = create_engine('mysql+mysqlconnector://ritesh:0808@localhost/stock_database')

# Partition and store data by year
for year, year_data in stock_data.groupby('Year'):
    # Write the data for each year to MySQL
    year_data.to_sql(f'stock_data_{year}', con=engine, if_exists='replace', index=False)
    
print("Stock data stored in MySQL database successfully.")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'ritesh'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

# MySQL database connection parameters
username = 'ritesh'
password = '0808'
host = 'localhost'  # or '127.0.0.1' if MySQL is running locally
port = '3306'  # MySQL default port
database = 'stock_database'

# Create a connection string
connection_string = f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}'

# Create a SQLAlchemy engine
engine = create_engine(connection_string)

# Execute a SQL query and fetch data into a pandas DataFrame
query = "SELECT * FROM your_table_name LIMIT 10"  # Example query, replace with your own
df = pd.read_sql(query, engine)

# Display the DataFrame
print(df)

# %%
pip install pandas sqlalchemy mysql-connector-python
